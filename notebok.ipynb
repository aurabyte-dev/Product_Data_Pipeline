# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.expand_frame_repr", False)
raw_df = pd.read_csv("data/raw/products_raw.csv")
raw_df.head()
# Out:
#          id    name price currency  created_at  updated_at
# 0  SKU-1001   shoes   799      SEK  2024-01-10  2024-01-10
# 1  SKU-1002   pants   520      SEK  2024/02/15  2024/02/15
# 2  SKU-1003  shirts   450      SEK         NaN         NaN
# 3       NaN  jacket  -200      SEK  2024-13-01  2024-13-01
# 4  SKU-1005     NaN   NaN      NaN         NaN         NaN

# %%
from pipeline.transform import clean_whitespace

clean_df = clean_whitespace(raw_df)
print(clean_df.head())
# Out:
#          id    name price currency  created_at  updated_at
# 0  SKU-1001   shoes   799      SEK  2024-01-10  2024-01-10
# 1  SKU-1002   pants   520      SEK  2024/02/15  2024/02/15
# 2  SKU-1003  shirts   450      SEK         NaN         NaN
# 3       NaN  jacket  -200      SEK  2024-13-01  2024-13-01
# 4  SKU-1005     NaN   NaN      NaN         NaN         NaN

# %%
from pipeline.transform import case_normalization

clean_df = case_normalization(clean_df)
print(clean_df.head())
# Out:
#          id    name price currency  created_at  updated_at
# 0  SKU-1001   Shoes   799      SEK  2024-01-10  2024-01-10
# 1  SKU-1002   Pants   520      SEK  2024/02/15  2024/02/15
# 2  SKU-1003  Shirts   450      SEK         NaN         NaN
# 3       NaN  Jacket  -200      SEK  2024-13-01  2024-13-01
# 4  SKU-1005     NaN   NaN      NaN         NaN         NaN

# %%
from pipeline.transform import standardize_date_format

clean_df = standardize_date_format(clean_df)
print(clean_df.head())
# Out:
#          id    name price currency  created_at  updated_at
# 0  SKU-1001   Shoes   799      SEK  2024-01-10  2024-01-10
# 1  SKU-1002   Pants   520      SEK  2024-02-15  2024-02-15
# 2  SKU-1003  Shirts   450      SEK         NaN         NaN
# 3       NaN  Jacket  -200      SEK  2024-13-01  2024-13-01
# 4  SKU-1005     NaN   NaN      NaN         NaN         NaN

# %%
from pipeline.transform import convert_to_datetime

clean_df = convert_to_datetime(clean_df)
print(clean_df)
# Out:
#           id           name          price currency created_at updated_at
# 0   SKU-1001          Shoes            799      SEK 2024-01-10 2024-01-10
# 1   SKU-1002          Pants            520      SEK 2024-02-15 2024-02-15
# 2   SKU-1003         Shirts            450      SEK        NaT        NaT
# 3        NaN         Jacket           -200      SEK        NaT        NaT
# 4   SKU-1005            NaN            NaN      NaN        NaT        NaT
# 5   SKU-1006  Designer Coat            NaN      SEK 2024-05-01 2024-05-01
# 6        NaN            Hat           free      SEK        NaT        NaT
# 7   SKU-1008         Gloves            120      NaN 2024-06-20 2024-06-20
# 8   SKU-1009          Socks             99      SEK 2024-02-01 2024-02-01
# 9   SKU-1010          Boots           1500      SEK 2024-02-15 2024-02-14
# 10  SKU-1011          Scarf            200      SEK 2024-03-01 2024-03-01
# 11  SKU-1012           Belt            300      SEK 2024-03-10 2024-03-10
# ...

# %%
from pipeline.transform import convert_to_numeric
clean_df = convert_to_numeric(clean_df)
print(clean_df)
# Out:
#           id           name     price currency created_at updated_at
# 0   SKU-1001          Shoes     799.0      SEK 2024-01-10 2024-01-10
# 1   SKU-1002          Pants     520.0      SEK 2024-02-15 2024-02-15
# 2   SKU-1003         Shirts     450.0      SEK        NaT        NaT
# 3        NaN         Jacket    -200.0      SEK        NaT        NaT
# 4   SKU-1005            NaN       NaN      NaN        NaT        NaT
# 5   SKU-1006  Designer Coat       NaN      SEK 2024-05-01 2024-05-01
# 6        NaN            Hat       NaN      SEK        NaT        NaT
# 7   SKU-1008         Gloves     120.0      NaN 2024-06-20 2024-06-20
# 8   SKU-1009          Socks      99.0      SEK 2024-02-01 2024-02-01
# 9   SKU-1010          Boots    1500.0      SEK 2024-02-15 2024-02-14
# 10  SKU-1011          Scarf     200.0      SEK 2024-03-01 2024-03-01
# 11  SKU-1012           Belt     300.0      SEK 2024-03-10 2024-03-10
# 12  SKU-1013            Cap      75.0      SEK 2024-04-01 2024-04-01
# ...

# %%
from pipeline.transform import missing_data

clean_df = missing_data(clean_df)
print(clean_df)
# Out:
#           id           name     price currency created_at updated_at  missing_data
# 0   SKU-1001          Shoes     799.0      SEK 2024-01-10 2024-01-10         False
# 1   SKU-1002          Pants     520.0      SEK 2024-02-15 2024-02-15         False
# 2   SKU-1003         Shirts     450.0      SEK        NaT        NaT          True
# 3        NaN         Jacket    -200.0      SEK        NaT        NaT          True
# 4   SKU-1005            NaN       NaN      NaN        NaT        NaT          True
# 5   SKU-1006  Designer Coat       NaN      SEK 2024-05-01 2024-05-01          True
# 6        NaN            Hat       NaN      SEK        NaT        NaT          True
# 7   SKU-1008         Gloves     120.0      NaN 2024-06-20 2024-06-20          True
# 8   SKU-1009          Socks      99.0      SEK 2024-02-01 2024-02-01         False
# 9   SKU-1010          Boots    1500.0      SEK 2024-02-15 2024-02-14         False
# ...

# %%
from pipeline.transform import date_violation

clean_df = date_violation(clean_df)
print(clean_df)
# Out:
#           id           name     price currency created_at updated_at  missing_data  date_violation
# 0   SKU-1001          Shoes     799.0      SEK 2024-01-10 2024-01-10         False           False
# 1   SKU-1002          Pants     520.0      SEK 2024-02-15 2024-02-15         False           False
# 2   SKU-1003         Shirts     450.0      SEK        NaT        NaT          True           False
# 3        NaN         Jacket    -200.0      SEK        NaT        NaT          True           False
# 4   SKU-1005            NaN       NaN      NaN        NaT        NaT          True           False
# 5   SKU-1006  Designer Coat       NaN      SEK 2024-05-01 2024-05-01          True           False
# 6        NaN            Hat       NaN      SEK        NaT        NaT          True           False
# 7   SKU-1008         Gloves     120.0      NaN 2024-06-20 2024-06-20          True           False
# ...

# %%
from pipeline.transform import duplicates

clean_df = duplicates(clean_df)
print(clean_df)
# Out:
#           id           name     price currency created_at updated_at  missing_data  date_violation  duplicates  price_outlier
# 0   SKU-1001          Shoes     799.0      SEK 2024-01-10 2024-01-10         False           False       False          False
# 1   SKU-1002          Pants     520.0      SEK 2024-02-15 2024-02-15         False           False       False          False
# 2   SKU-1003         Shirts     450.0      SEK        NaT        NaT          True           False       False          False
# 3        NaN         Jacket    -200.0      SEK        NaT        NaT          True           False       False          False
# 4   SKU-1005            NaN       NaN      NaN        NaT        NaT          True           False       False          False
# 5   SKU-1006  Designer Coat       NaN      SEK 2024-05-01 2024-05-01          True           False       False          False
# ...

# %%
from pipeline.transform import negative_value

clean_df = negative_value(clean_df)
print(clean_df)
# Out:
#           id           name     price currency created_at updated_at  missing_data  date_violation  duplicates  price_outlier  negative_price
# 0   SKU-1001          Shoes     799.0      SEK 2024-01-10 2024-01-10         False           False       False          False           False
# 1   SKU-1002          Pants     520.0      SEK 2024-02-15 2024-02-15         False           False       False          False           False
# 2   SKU-1003         Shirts     450.0      SEK        NaT        NaT          True           False       False          False           False
# 3        NaN         Jacket    -200.0      SEK        NaT        NaT          True           False       False          False            True
# 4   SKU-1005            NaN       NaN      NaN        NaT        NaT          True           False       False          False           False
# ...

# %%
from pipeline.transform import price_outliers_high

clean_df = price_outliers_high(clean_df)
print(clean_df)
# Out:
#           id           name     price currency created_at updated_at  missing_data  date_violation  duplicates  price_outlier  negative_price
# 0   SKU-1001          Shoes     799.0      SEK 2024-01-10 2024-01-10         False           False       False          False           False
# 1   SKU-1002          Pants     520.0      SEK 2024-02-15 2024-02-15         False           False       False          False           False
# 2   SKU-1003         Shirts     450.0      SEK        NaT        NaT          True           False       False          False           False
# 3        NaN         Jacket    -200.0      SEK        NaT        NaT          True           False       False          False            True
# 4   SKU-1005            NaN       NaN      NaN        NaT        NaT          True           False       False          False           False
# ...

# %%
from pipeline.transform import date_violation

clean_df = date_violation(clean_df)
print(clean_df)
# Out:
#           id           name     price currency created_at updated_at  missing_data  date_violation  duplicates  price_outlier  negative_price
# 0   SKU-1001          Shoes     799.0      SEK 2024-01-10 2024-01-10         False           False       False          False           False
# 1   SKU-1002          Pants     520.0      SEK 2024-02-15 2024-02-15         False           False       False          False           False
# 2   SKU-1003         Shirts     450.0      SEK        NaT        NaT          True           False       False          False           False
# 3        NaN         Jacket    -200.0      SEK        NaT        NaT          True           False       False          False            True
# 4   SKU-1005            NaN       NaN      NaN        NaT        NaT          True           False       False          False           False
# ...

# %%
from pipeline.transform import categorize_for_review

clean_df = categorize_for_review(clean_df)
print(clean_df)
# Out:
#           id           name     price currency created_at updated_at  missing_data  date_violation  duplicates  price_outlier  negative_price                   review_reason
# 2   SKU-1003         Shirts     450.0      SEK        NaT        NaT          True           False       False          False           False                  Missing data;
# 3        NaN         Jacket    -200.0      SEK        NaT        NaT          True           False       False          False            True  Missing data; Negative price;
# 4   SKU-1005            NaN       NaN      NaN        NaT        NaT          True           False       False          False           False                  Missing data;
# 5   SKU-1006  Designer Coat       NaN      SEK 2024-05-01 2024-05-01          True           False       False          False           False                  Missing data;
# ...

# %%
review_df= categorize_for_review(clean_df)
print(review_df)
# Out:
#           id           name     price currency created_at updated_at  missing_data  date_violation  duplicates  price_outlier  negative_price                   review_reason
# 2   SKU-1003         Shirts     450.0      SEK        NaT        NaT          True           False       False          False           False                  Missing data;
# 3        NaN         Jacket    -200.0      SEK        NaT        NaT          True           False       False          False            True  Missing data; Negative price;
# 4   SKU-1005            NaN       NaN      NaN        NaT        NaT          True           False       False          False           False                  Missing data;
# 5   SKU-1006  Designer Coat       NaN      SEK 2024-05-01 2024-05-01          True           False       False          False           False                  Missing data;
# ...

# %%
missing_price = clean_df["price"].isna().sum()
print(missing_price)
# Out:
# 5

# %%
price_missing = clean_df[
    clean_df["price"].isna() & 
    clean_df["name"].notna() &
    clean_df["id"].notna()]
print(price_missing[["name", "id", "price"]])
# Out:
#              name        id  price
# 5   Designer Coat  SKU-1006    NaN
# 42       Cardigan  SKU-1043    NaN
# 51           Coat  SKU-1052    NaN

# %%
count_products = len(clean_df["id"].notna())
print(count_products)
# Out:
# 21

# %%
def product_count(clean_df):
    count_products = len(clean_df["id"].notna())
    return count_products
print(count_products)
# Out:
# 21

# %%
def missing_price(clean_df):
    product_missing_price = (
        clean_df["id"].notna() &
        clean_df["price"].isna()).sum()
    return product_missing_price
print(product_missing_price)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[202], line 6
#       2     product_missing_price = (
#       3         clean_df["id"].notna() &
#       4         clean_df["price"].isna()).sum()
#       5     return product_missing_price
# ----> 6 print(product_missing_price)
#
# NameError: name 'product_missing_price' is not defined

# %%
top_10_expensive = clean_df.nlargest(10, "price")
print(top_10_expensive)
# Out:
#           id           name     price currency created_at updated_at  missing_data  date_violation  duplicates  price_outlier  negative_price    review_reason
# 38  SKU-1039           Coat  999999.0      SEK 2024-10-15 2024-10-15         False           False       False           True           False  Price outlier;
# 20  SKU-1021           Ring   25000.0      SEK 2024-06-05 2024-06-05         False           False       False           True           False  Price outlier;
# 19  SKU-1020          Watch   15000.0      SEK 2024-06-01 2024-06-01         False           False       False           True           False  Price outlier;
# 31  SKU-1032           Suit    5000.0      SEK 2024-09-01 2024-09-01         False           False       False           True           False  Price outlier;
# 39  SKU-1040          Parka    4500.0      SEK 2024-11-01 2024-11-01         False           False       False           True           False  Price outlier;
# ...

# %%
top_10_cheap = clean_df.nsmallest(10, "price")
print(top_10_cheap)
# Out:
#           id      name   price currency created_at updated_at  missing_data  date_violation  duplicates  price_outlier  negative_price                   review_reason
# 3        NaN    Jacket  -200.0      SEK        NaT        NaT          True           False       False          False            True  Missing data; Negative price;
# 14  SKU-1015    Hoodie   -50.0      SEK 2024-04-15 2024-04-15         False           False       False          False            True                Negative price;
# 13  SKU-1014   T-Shirt     0.0      SEK 2024-04-10 2024-04-10         False           False       False          False            True                Negative price;
# 7   SKU-1008    Gloves   120.0      NaN 2024-06-20 2024-06-20          True           False       False          False           False                  Missing data;
# ...

# %%
extreme_outliers = clean_df[(clean_df["price"] < Q1) | (clean_df["price"] > upper_bound)]
top_10_outliers = extreme_outliers.sort_values("price", ascending=False).head(10)
print(top_10_outliers[["name", "price"]])
# Out:
#        name     price
# 38     Coat  999999.0
# 20     Ring   25000.0
# 19    Watch   15000.0
# 7    Gloves     120.0
# 13  T-Shirt       0.0
# 14   Hoodie     -50.0
# 3    Jacket    -200.0
