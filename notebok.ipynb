# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
raw_df = pd.read_csv("data/raw/products_raw.csv")
print(raw_df.head())
# Out:
#          id    name price currency  created_at  updated_at
# 0  SKU-1001   shoes   799      SEK  2024-01-10  2024-01-10
# 1  SKU-1002   pants   520      SEK  2024/02/15  2024/02/15
# 2  SKU-1003  shirts   450      SEK         NaN         NaN
# 3       NaN  jacket  -200      SEK  2024-13-01  2024-13-01
# 4  SKU-1005     NaN   NaN      NaN         NaN         NaN

# %%
from pipeline.clean import clean_whitespace

clean_df = clean_whitespace(raw_df)
print(clean_df.head())
# Out:
#          id    name price currency  created_at  updated_at
# 0  SKU-1001   shoes   799      SEK  2024-01-10  2024-01-10
# 1  SKU-1002   pants   520      SEK  2024/02/15  2024/02/15
# 2  SKU-1003  shirts   450      SEK         NaN         NaN
# 3       NaN  jacket  -200      SEK  2024-13-01  2024-13-01
# 4  SKU-1005     NaN   NaN      NaN         NaN         NaN

# %%
from pipeline.clean import case_normalization

clean_df = case_normalization(clean_df)
print(clean_df.head())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 from pipeline.clean import case_normalization
#       3 clean_df = case_normalization(clean_df)
#       4 print(clean_df.head())
#
# ImportError: cannot import name 'case_normalization' from 'pipeline.clean' (/Users/alex/Documents/github/Data_Platform/Product_Data_Pipeline/pipeline/clean.py)

# %%
from pipeline.clean import case_normalization


def clean_whitespace(raw_df):
    # Remove whitespace from string columns

    clean_df = raw_df.copy()

    string_colums = clean_df.select_dtypes(include=['object']).columns
    for col in string_colums:
        clean_df[col] = clean_df[col].str.strip()
    
    return clean_df


def case_normalization(clean_df):
    # Change title to uppercase

    clean_df = clean_df.copy()

    string_colums = clean_df.select_dtypes(include=['object']).columns
    for col in string_colums:
        clean_df[col] = clean_df[col].str.title()
    
    return clean_df
